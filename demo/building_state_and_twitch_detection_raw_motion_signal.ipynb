# %% [markdown]
# # State detection pipeline on motion energy
# Binarises motion into prospective Active/Awake and Rest/Sleep state & performs twitch detection during Rest
#
# - Step by step detection procedure
#
# - check maybe sav golay for smoothing better ?  https://scipy-cookbook.readthedocs.io/items/SavitzkyGolay.html
#
#
# - Check twitch bursts -> I think its the step it removes too many twithces
# - Export annotated movie and validate (could make a small GUI for that to add on excel (save as curated_xls to not overwrite)
# - Once curated - check how many motions and twitches are TP FP TN (TN we cant have)
# * Once have the onsets - do PMTHs (single and avgs) for twitch and for awake motion
# This requires the s2p non avged (rerun on server)
#
# - If detection on non avg - then match back the times /3 and closest ? check carmens ds for other analysis (correlations (motion coupling) vs population coupling, decoding etc.
# -
# - Check onset and offset to be as smooth and not affected by smoothing & avging
# -
# - get percentages of validated detection and curated onsets and offsets and twithces and make pmths and all analysis state dependent (for validation -> GUI otuput)

# %%
import os
# going to root directory (if not there yet)
current_dir = os.getcwd().split('/')[-1]
if current_dir != 'pixelNMF': 
    os.chdir('..')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\zaggila\\Documents\\pixelNMF'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tifffile
from skimage import filters
from scipy.ndimage import label, binary_closing

from pathlib import Path
from PIL import Image
import imageio
import cv2

from patchnmf.data_io import *
from patchnmf.analyse.videography_compute import *
from patchnmf.analyse.videography_plot import *

# %%
os.getcwd()
# Out:
# 'C:\\Users\\zaggila\\Documents\\pixelNMF'

# %%
# setting common plot params 
from matplotlib import rcParams

rcParams['figure.figsize'] = [20, 4]
rcParams['font.size'] = 15
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
rcParams['figure.autolayout'] = True

# %%
def mkdir(path):
    if not os.path.exists(path): os.makedirs(path)
    return path

# %%
data_path = rf'C:\Users\zaggila\Documents\pixelNMF\data'
sessions = sorted([f for f in os.listdir(data_path) if f.endswith('_cell_control')])
print(f'All sessions: {sessions}')
# Out:
# All sessions: ['sz89_2024-06-04_a_cell_control', 'sz89_2024-06-06_a_cell_control', 'sz89_2024-06-07_a_cell_control', 'sz90_2024-06-05_a_cell_control', 'sz90_2024-06-06_a_cell_control', 'sz90_2024-06-07_a_cell_control', 'sz91_2024-06-05_b_cell_control', 'sz92_2024-06-06_a_cell_control', 'sz92_2024-06-07_a_cell_control']

# %%
ds = 'sz89_2024-06-06_a_cell_control'

subject_path = os.path.join(data_path, ds) # choose one specifc ds 
movie_path = os.path.join(subject_path, 'cam_crop.tif')

#load sleap output
files = os.listdir(subject_path)
csv_files = [f for f in files if f.endswith('.csv')]

# Check if there is exactly one CSV file
if len(csv_files) == 1:
    # Load the CSV file into a DataFrame
    sleap_output_path = os.path.join(subject_path, csv_files[0])  # Get full path to the CSV file
    sleap_output = pd.read_csv(sleap_output_path)  # Pass the file path
    print(f"Loaded {csv_files[0]}")
else:
    if len(csv_files) == 0:
        raise FileNotFoundError("No CSV files found")
    else:
        raise FileExistsError("Multiple CSV files found. Please ensure there is only one CSV file in the subject directory.")

save_dir = subject_path
save_dir_videography = mkdir(f'{save_dir}/videography_processing_non_avg')
save_dir_videography = Path(save_dir_videography)
# Out:
# Loaded sz89_2024-06-06_a_analysis.csv

# %% [markdown]
# # Set parameters

# %%
gaussian_sigma = 5

# Thresholds for binarisation
threshold_binary = 'otsu'  # threshold for binary: a/r state detcetion -
threshold_twitch = 'li' #threshold for twitch detection (more permissive -> detect more/lose less)
# thresh_factor = 1.0  # used for "mean+std" option

# Twitch detection thresholds
framerate = 15  # Hz   # Careful: set rifght framerate (avged or raw motion) (also for time thresholds)

active_motion_duration_min = framerate * 1 # 1 sec 
long_active_motion_duration_min = framerate * 3 # at least 3 seconds to be considered a long awake motion eg run 
twitch_duration_max = active_motion_duration_min
twitch_min_distance_from_active = framerate * 3  # at least 3 sec away from awake motion to be detected as twitch 
print(f' max_twitch_allowed: {twitch_duration_max/framerate} sec')
# Out:
#  max_twitch_allowed: 1.0 sec

# %% [markdown]
# # Compute/Load motion energy

# %%
def compute_motion_energy(movie_path=None, xrange=None, yrange=None, save_path=None):
    """
    Compute motion energy from a multi-frame TIFF movie of mouse movement.

    Parameters:
    - movie_path: Path to the multi-frame TIFF file (None, unless ititial run)
    - xrange: Range of x-values to crop the image (optional)
    - yrange: Range of y-values to crop the image (optional)
    - save_path: Path to save the motion energy result (optional)
    """
    
    #check if motion energy has already been computed, if that's the case load it

    motion_energy_path = os.path.join(save_path,"motion_energy.npy")
    if os.path.exists(motion_energy_path):

        print(f'Motion energy already computed. Loading from {motion_energy_path}')
        motion_energy = np.load(motion_energy_path)
        return motion_energy

    if not movie_path:

        raise ValueError('Please provide the tiff for the initial run') 
    
    # Load the TIFF movie (multi-frame TIFF)
    movie = tifffile.imread(movie_path)
    num_frames, height, width = movie.shape

    print(f'Loaded movie with {num_frames} frames, height={height}, width={width}')

    # Initialize motion energy array
    motion_energy = np.zeros(num_frames)
    img_prev = movie[0]

    # Iterate over the frames and compute motion energy
    for i in range(1, num_frames):
        img = movie[i]

        # Compute motion energy as squared differences between consecutive frames
        diff = img - img_prev
        squared_diff = diff ** 2
        motion_energy[i] = np.sum(squared_diff)

        # Update img_prev for the next iteration
        img_prev = img

        # Print progress every 1000 frames
        if i % 1000 == 0:
            print(f'Done computing for {i}/{num_frames} frames')
    
    # Normalize motion energy
    motion_energy = motion_energy[1:]  # Skip the first frame (no previous frame to compare)
    motion_energy /= np.max(motion_energy)
    
    return motion_energy

# %%
motion_energy = compute_motion_energy(movie_path=movie_path, xrange=None, yrange=None, save_path=subject_path) #if first run, provide movie_path

# if len(motion_energy) != 3600:
#     motion_energy = pad(motion_energy)
#     motion_energy = average_frames(motion_energy, avg_block = 5) # avg as needed 

plt.plot(motion_energy)
plt.show()
# Out:
# Motion energy already computed. Loading from C:\Users\zaggila\Documents\pixelNMF\data\sz89_2024-06-06_a_cell_control\motion_energy.npy

# %%
# # Dim Reduction (just for fun)
# from sklearn.preprocessing import StandardScaler
# from numpy.lib.stride_tricks import sliding_window_view

# # window_size = 30  # in frames
# # stride = 5
# # X = sliding_window_view(motion_energy, window_shape=window_size)[::stride]
# X = StandardScaler().fit_transform(motion_energy)  # normalize per window

# %%
# X.shape

# %%
# from sklearn.cluster import KMeans

# window_size = 30       # ~1 sec if fs=30 Hz
# stride = 5             # ~0.17 sec step
# n_clusters = 3         # e.g. rest, twitch, active

# # ----------------------------
# # 2. WINDOWING
# # ----------------------------
# # Make overlapping windows
# windows = sliding_window_view(motion_energy, window_shape=window_size)[::stride]

# # Optional: Normalize each window (across time)
# X = StandardScaler().fit_transform(windows)

# # ----------------------------
# # 3. UMAP DIMENSIONALITY REDUCTION
# # ----------------------------
# reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)
# embedding = reducer.fit_transform(X)  # shape (n_windows, 2)

# # ----------------------------
# # 4. KMeans CLUSTERING
# # ----------------------------
# kmeans = KMeans(n_clusters=n_clusters, random_state=42)
# labels = kmeans.fit_predict(embedding)  # shape (n_windows,)

# # ----------------------------
# # 5. VISUALIZE EMBEDDING
# # ----------------------------
# plt.figure(figsize=(6, 5))
# plt.scatter(embedding[:, 0], embedding[:, 1], c=labels, cmap='Spectral', s=10)
# plt.title("UMAP Embedding of Motion Energy")
# plt.xlabel("UMAP 1")
# plt.ylabel("UMAP 2")
# plt.colorbar(label="Cluster")
# plt.tight_layout()
# plt.show()

# # ----------------------------
# # 6. MAP BACK TO TIME
# # ----------------------------
# # Create full-length time series of labels
# cluster_trace = np.full(len(motion_energy), np.nan)
# for i, label in enumerate(labels):
#     center = i * stride + window_size // 2
#     if center < len(cluster_trace):
#         cluster_trace[center] = label

# %%
length_acts = len(motion_energy)
# for plotting xticks to seconds
frame_ticks = range(0, length_acts+ 100, 300)  # 300 frames is 100 sec
second_ticks = [int(tick/framerate) for tick in frame_ticks]   # Convert to seconds

# %% [markdown]
# # Smooth motion energy

# %%
# Smooth motion energy

from scipy.signal import savgol_filter

# Define window size and polynomial order
# Window length must be odd and >= polyorder + 2
window_length = 101  # In Butt paper they do 1s window so for us 15 or 31 approx 2 sTry 5, 7, 11 depending on signal noise level and fs
polyorder = 3   #  depends on signal complexity 

smoothed_sav_gol =  savgol_filter(motion_energy, window_length=window_length, polyorder=polyorder, mode='interp')
                                       
# smoothed_motion_energy = smooth_with_gaussian(motion_energy, sigma=gaussian_sigma)
smoothed_motion_energy = smoothed_sav_gol 

plt.plot(motion_energy, linewidth=2)
plt.plot(smoothed_motion_energy, linewidth=2)
plt.plot(smoothed_sav_gol, linewidth=1)
plt.show()

# %%
# threshold = np.percentile(motion_energy, 90)  # Example threshold
# onsets_orig = np.where(motion_energy > threshold)[0]
# onsets_sg = np.where(smoothed_sav_gol > threshold)[0]

# plt.plot(motion_energy, label="Original", alpha=0.5)
# plt.plot(smoothed_sav_gol, label="Sav-Golay", alpha=0.7)
# plt.vlines(onsets_orig, ymin=0, ymax=max(motion_energy), color='red', linestyle='--', label='Orig Onsets')
# plt.vlines(onsets_sg, ymin=0, ymax=max(motion_energy), color='green', linestyle=':', label='SG Onsets')
# plt.legend()
# plt.title("Onset Comparison")
# plt.show()

# %%
# # First derivative
# d_orig = np.gradient(motion_energy)
# d_gauss = np.gradient(smoothed_motion_energy)
# d_sg = np.gradient(smoothed_sav_gol)

# plt.plot(d_orig, label='Original d/dt', linewidth=2)
# plt.plot(d_gauss, label='Gaussian d/dt', linestyle='--')
# plt.plot(d_sg, label='Sav-Golay d/dt', linestyle=':')
# # plt.ylim(0)
# plt.legend()
# plt.title("Derivative Comparison")
# plt.show()

# %%
smoothed_motion_energy = smoothed_sav_gol

# %%
# from scipy.signal import savgol_filter

# motion_energy_smooth_savgol = savgol_filter(motion_energy, window_length=10, polyorder=2)
# plt.plot(motion_energy)
# plt.plot(motion_energy_smooth_savgol, c='lime')
# plt.plot(smoothed_motion_energy, c='r')

# plt.show()

# %% [markdown]
# # Choose statistical threshold for binarisation
#
# Otsu should theoretically work if there is active-wake transition

# %%
def compute_thresholds_for_bin_state_detection(motion_signal, title='', save_dir=None, plot=True):
    '''
    Compute statistical thresholds to use for threshold-based state detection (active/awake - rest)
    Here we use: Otsu (prefer if binary distribution), Li (mutliple peak distribution), or mean+sd (gaussian distribution)
    '''
    
    # mean+sd threshold 
    motion_mean = np.mean(motion_signal)
    motion_sd = np.std(motion_signal)

    threshold_motion_mean_sd = motion_mean + motion_sd

    threshold_motion_li = filters.threshold_li(motion_signal)

    threshold_motion_otsu = filters.threshold_otsu(motion_signal)

    if plot:
        plt.figure(figsize=(5, 5), dpi=300)
        plt.title(f'{title}')
        plt.hist(motion_signal, bins=70, alpha=0.9)

        # mark threshold lines
        plt.axvline(x=threshold_motion_mean_sd, color='red', label='mean + sd', linestyle='--')
        plt.axvline(x=threshold_motion_otsu, color='salmon', label='Otsu', linestyle='--')
        plt.axvline(x=threshold_motion_li, color='darkred', label='Li', linestyle='--')

        plt.legend()
        plt.savefig(save_dir / f'{title}.png')
        plt.show()

    return threshold_motion_mean_sd, threshold_motion_li, threshold_motion_otsu

# %%
threshold_motion_mean_sd, threshold_motion_li, threshold_motion_otsu = compute_thresholds_for_bin_state_detection(smoothed_motion_energy, title='stat_thresholds_for_bin_state_detection', save_dir=save_dir_videography, plot=True)

# %% [markdown]
# # Choose binarisation threshold

# %%
binary_threshold = threshold_motion_otsu

# %% [markdown]
# # Binarise motion energy

# %%
def binarise_motion(motion_signal, binary_threshold, min_duration, min_inactive_gap=9):
    '''
    Binarises motion signal (eg mot_en) into 0s (rest) and 1s (active)
    input params:
    motion_signal: motion energy or other
    binary_threshold: sts threshold (li, otsu or mean_sd for state detection)
    min_di=uration: min_duration threshold to be detected as awake/active motion
    
    returns:
    bin_motion_signal: bin array of 0s and 1s 
    inds_active_state: indices of frames whens state is active
    inds_rest_state: indices of frames when state is rest/inactive 

    '''
    
    bin_motion_signal = np.zeros(len(motion_signal), dtype=int)

    # get boolean array 
    
    all_active_motions_detected = motion_signal > binary_threshold 

    # labels continuous segments that pass the threshold 

    labeled_array, n_features = label(all_active_motions_detected) #how many active motions where found 
    
    for i in range(1, n_features+1):
        segment = np.where(labeled_array == i)[0]
        if len(segment) > min_duration:
            bin_motion_signal[segment] = 1

    inds_active_state = np.where(bin_motion_signal ==1)
    inds_rest_state = np.where(bin_motion_signal ==0)
    
    return bin_motion_signal, inds_active_state, inds_rest_state

# %%
bin_motion_energy, inds_active_state, inds_rest_state =  binarise_motion(smoothed_motion_energy, binary_threshold=binary_threshold, min_duration=active_motion_duration_min, min_inactive_gap=9)

# %% [markdown]
# # Plot binary motion (Active - 1 / Rest - 0)

# %%
plt.plot(bin_motion_energy, color='orange', linewidth=2)
plt.plot(smoothed_motion_energy, linewidth=2)
plt.title('binary motion_energy', fontsize=25)
plt.axhline(y=threshold_motion_otsu, color='red', linestyle='--', label='binary threshold', linewidth=3)
# plt.savefig(save_dir_videography + 'thresholded_binarised_motion_energy.png')
plt.show()

# %%
from scipy.signal import find_peaks

# %%
# # Compute first derivative
# diff_motion = np.gradient(motion_energy)

# # Find peaks in the derivative where slope is steep
# peaks, _ = find_peaks(diff_motion, height=some_slope_threshold)

# %%
# from scipy.fft import fft
# power = np.abs(fft(motion_energy[0:3600]))

# %% [markdown]
# # Define onsets and offsets of active motion

# %%
def get_onsets(bin_motion):
    onsets = np.where((bin_motion[1:] == 1) & (bin_motion[:-1] == 0))[0] + 1 #[0] specific to stcuture of array
    # if bin_motion[0] == 1:       
    return onsets
    
def get_offsets(bin_motion):
    offsets = np.where((bin_motion[1:] == 0) & (bin_motion[:-1] == 1))[0] + 1 #[0] specific to stcuture of array
    return offsets

# %%
active_motion_onsets = get_onsets(bin_motion_energy)
active_motion_offsets = get_offsets(bin_motion_energy)

# %% [markdown]
# # Classify Active (awake) motions to short / long and visualise them

# %%
def classify_active_motion_segments(bin_motion_signal, motion_signal, short_threshold, long_threshold):
    """
    Classify active/awake motion segments into short (1–3 sec), long (>3 sec), and too short (<1 sec, those are exluded in awake motion detection and set to 0).

    Parameters:
    - bin_motion_signal: 1D array of HMM or thresholded motion states (1 for active, 0 for inactive)
    - motion_signal: 1D array of motion energy values
    - short_threshold: in frames, minimum duration for short active motions (e.g., 3 or 1s at 3Hz)
    - long_threshold: in frames, minimum duration for long active motions (e.g., 9 or 3s at 3Hz)

    Returns:
    - bin_short_active_motion: binary array marking short motions (1-3s)
    - bin_long_active_motion: binary array marking long motions (>3s)
    - bin_too_short_active_motion: binary array marking short blips (<1s)
    - and correspondings inds of long, short or too short (excluded) motions
    """
    labeled_array, num_features = label(bin_motion_signal == 1)

    bin_short_active_motion = np.zeros(len(motion_signal), dtype=int)
    bin_long_active_motion = np.zeros(len(motion_signal), dtype=int)
    bin_too_short_active_motion = np.zeros(len(motion_signal), dtype=int)

    for i in range(1, num_features + 1):
        segment = np.where(labeled_array == i)[0]

        if len(segment) > long_threshold:
            bin_long_active_motion[segment] = 1
        elif len(segment) > short_threshold:
            bin_short_active_motion[segment] = 1
        elif len(segment) > 0: # but shorter than short threshold 
            bin_too_short_active_motion[segment] = 0 # mark as inactive 

        long_active_motion_inds = np.where(bin_long_active_motion==1)[0]
        short_active_motion_inds = np.where(bin_short_active_motion==1)[0]
        too_short_active_motion_inds = np.where(bin_too_short_active_motion==1)[0]

            
    return bin_short_active_motion, short_active_motion_inds, bin_long_active_motion, long_active_motion_inds, bin_too_short_active_motion, too_short_active_motion_inds

# %%
# classify active motions detected 
bin_short_active_motion, short_active_motion_inds, bin_long_active_motion, long_active_motion_inds, bin_too_short_active_motion, too_short_active_motion_inds = classify_active_motion_segments(
    bin_motion_energy,
    motion_energy,
    short_threshold=active_motion_duration_min,
    long_threshold=long_active_motion_duration_min
)

# plot classified active motions detected 
plot_active_motion_classification_subplots(
    motion_signal=motion_energy,
    smoothed_motion_signal=smoothed_motion_energy,
    bin_motion_energy=bin_motion_energy,
    bin_long_active_motion=bin_long_active_motion,
    bin_short_active_motion=bin_short_active_motion,
    long_active_motion_inds=long_active_motion_inds,
    short_active_motion_inds=short_active_motion_inds,
    threshold=threshold_motion_otsu,
    save_path=save_dir_videography / 'subplots_bin_motion_energy_classified.png',
)
# Out:
# Saved plot to: C:\Users\zaggila\Documents\pixelNMF\data\sz89_2024-06-06_a_cell_control\videography_processing_non_avg\subplots_bin_motion_energy_classified.png

# %%
# turn indices into continuous segments eg 25-100 is active seg 1, 500-805 active seg 2 etc
active_segments = get_active_segments(inds_active_state[0]) #all not only long
long_active_segments = get_active_segments(long_active_motion_inds) #all not only long , already numpy
# if len(short_active_segments)>1: #to solve not defined
    # short_active_segments = get_active_segments(short_active_motion_inds)

# %% [markdown]
# # Twitch detection
#
# TODO: maybe low pass filter rest periods to remove noises

# %%
rest_period = motion_energy[inds_rest_state] #identify periods of low motion energy ==0 (non smoothed (!))
rest_period = rest_period.flatten()

# %%
log_signal = np.log1p(rest_period)  # log1p avoids issues with zeroes
threshold_log= np.percentile(rest_period, 95)

# %%
from statsmodels.robust import mad

def compute_thresholds_for_bin_state_detection(motion_signal, save_dir=None, plot=True):
    '''
    Compute statistical thresholds to use for threshold-based state detection (active/awake - rest)
    Here we use: Otsu (prefer if binary distribution), Li (mutliple peak distribution), or mean+sd (gaussian distribution)
    '''
    
    # mean+sd threshold 
    motion_mean = np.mean(motion_signal)
    motion_sd = np.std(motion_signal)

    threshold_motion_mean_sd = motion_mean + 3*motion_sd

    threshold_motion_li = filters.threshold_li(motion_signal)

    threshold_motion_otsu = filters.threshold_otsu(motion_signal)

    threshold_95 = np.percentile(motion_signal, 95) 

    # log_signal = np.log1p(motion_signal)  # log1p avoids issues with zeroes
    # threshold_log= np.percentile(motion_signal, 95)

    med = np.median(motion_signal)
    mad_val = mad(motion_signal)
    threshold_mad = med + 3 * mad_val  # 3x MAD is analogous to ~3σ in normal data

    if plot:
        plt.figure(figsize=(5, 5), dpi=300)
        plt.title('stat thresholds on mot_en')
        plt.hist(motion_signal, bins=70, alpha=0.9)

        # mark threshold lines
        plt.axvline(x=threshold_motion_mean_sd, color='red', label='mean + sd', linestyle='--')
        plt.axvline(x=threshold_motion_otsu, color='salmon', label='Otsu', linestyle='--')
        plt.axvline(x=threshold_motion_li, color='darkred', label='Li', linestyle='--')
        # plt.axvline(x=threshold_log, color='pink', label='95 threshold on log_motion')
        plt.axvline(x=threshold_mad, color='pink', label='threshold mad', linestyle='--')
        plt.axvline(x=threshold_95, color='purple', label='threshold 95%', linestyle='--')


        plt.legend()
        plt.savefig(save_dir / 'binary_state_thresholds.png')
        plt.show()

    return threshold_motion_mean_sd, threshold_motion_li, threshold_motion_otsu, threshold_mad, threshold_95

# %%
twitch_threshold_motion_mean_sd, twitch_threshold_motion_li, twitch_threshold_motion_otsu, threshold_mad, threshold_95 = compute_thresholds_for_bin_state_detection(rest_period, save_dir=save_dir_videography, plot=True)

# %% [markdown]
# # Choose twitch threshold

# %%
# choose a threshold 
# twitch_threshold = twitch_threshold_li #more permissive of twitches --> more twitches detected (pre-filtering)

twitch_threshold = threshold_95

# %%
inds_twitches_unfiltered = np.where(rest_period > twitch_threshold) #inds of prospective twitches (in array of low motion energy) careful its on the size of low motion array
inds_twitches_unfiltered = inds_rest_state[0][inds_twitches_unfiltered]

# %%
unfiltered_putative_twitches_segments = find_sequential_groups(inds_twitches_unfiltered)
len(unfiltered_putative_twitches_segments)
# Out:
# 279

# %%
def binarise_twitch(motion_energy, twitch_segments):

    # Initialize bin_twitch   
    bin_twitch = np.zeros(len(motion_energy))

    # flatten the nested list
    flat_inds = [idx for segment in twitch_segments for idx in segment] # filtered corrected twitch segments 

    print("Flattened Indices:", flat_inds)

    # Assign 1 to twitch inds
    for idx in flat_inds:
        if idx < len(motion_energy):  # Ensure index is within bounds
            bin_twitch[idx] = 1
            print(f"Assigning 1 at column {idx}")
        else:
            print(f"Skipping out-of-bounds index: {idx}")
    return bin_twitch

# %%
bin_putative_twitch = binarise_twitch(motion_energy, unfiltered_putative_twitches_segments) #segs
# Out:
# Flattened Indices: [101, 117, 135, 136, 138, 200, 205, 207, 261, 262, 263, 264, 266, 273, 280, 300, 301, 387, 391, 605, 606, 608, 609, 611, 612, 614, 619, 629, 641, 675, 676, 677, 680, 681, 682, 732, 735, 737, 765, 776, 780, 785, 1004, 1008, 1010, 1055, 1088, 1089, 1100, 1101, 1108, 1117, 1120, 1156, 1164, 1206, 1207, 1432, 1433, 1434, 1441, 1442, 1444, 1448, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 2441, 2447, 2448, 2452, 2453, 2454, 2455, 2456, 2457, 2458, 2461, 2463, 2464, 2465, 2466, 2468, 2470, 2472, 2485, 2654, 2656, 2659, 2661, 2930, 2947, 2960, 2961, 2963, 2964, 2965, 3282, 3285, 3286, 3291, 3292, 3295, 3405, 3408, 3410, 3411, 3412, 3413, 4194, 4204, 4205, 4232, 4233, 4234, 4236, 4237, 4241, 4413, 4414, 4415, 4418, 4420, 4421, 4424, 4521, 4522, 4524, 4585, 4637, 4641, 4642, 4643, 4652, 4653, 4654, 4675, 4682, 4683, 4684, 4686, 4687, 4688, 4693, 4696, 4697, 4704, 4714, 4817, 4819, 4826, 4909, 4910, 4911, 4912, 4913, 4915, 4928, 4929, 4930, 4934, 4935, 4946, 4948, 4951, 4954, 4955, 4963, 4965, 4980, 5086, 5106, 5107, 5108, 5109, 5111, 5128, 5129, 5134, 5135, 5168, 5169, 5171, 5173, 5174, 6066, 6067, 6068, 6070, 6071, 6072, 6095, 6096, 6099, 6101, 6440, 6441, 6442, 6443, 6444, 6448, 6453, 6454, 6455, 6456, 6460, 6697, 6853, 6855, 7029, 7034, 7106, 7108, 7112, 7113, 7118, 7131, 7144, 7174, 7175, 7178, 7179, 7182, 7184, 7186, 7364, 7366, 7369, 7578, 7639, 7641, 7642, 7653, 7654, 7655, 7657, 7658, 7670, 7671, 8446, 8447, 8450, 8451, 8632, 8633, 8634, 8635, 8637, 8797, 8798, 8799, 8800, 8801, 8984, 8985, 8986, 8987, 8988, 8990, 8992, 9033, 9034, 9035, 9037, 9038, 9039, 9041, 9042, 9044, 9045, 9048, 9049, 9051, 9053, 9055, 9056, 9057, 9608, 9609, 9611, 9612, 9621, 10348, 10349, 10350, 10375, 10376, 10379, 10607, 10608, 10610, 10740, 10795, 10797, 10798, 10799, 10938, 11115, 11117, 11171, 11172, 11173, 11174, 11175, 11176, 11300, 11301, 11302, 11305, 11306, 11307, 11308, 11313, 11315, 11316, 11320, 12049, 12053, 12324, 12325, 12327, 12937, 12938, 12939, 12941, 12945, 12946, 12947, 13134, 13209, 13210, 13211, 13212, 13214, 13381, 13382, 13384, 13676, 13730, 13777, 13778, 13780, 13782, 13783, 13786, 14272, 14282, 14283, 14286, 14516, 14517, 14518, 14519, 14520, 14521, 14525, 14527, 14529, 14531, 14535, 14537, 14539, 14542, 14546, 14548, 14696, 14697, 14700, 14706, 14723, 14746, 14895, 14897, 14898, 14899, 14900, 14901, 14908, 14909, 14910, 14911, 14915, 14925, 14974, 14978, 14979, 14980, 14984, 14985, 14986, 14988, 14989, 14991, 14994, 14997, 15001, 15003, 15006, 15093, 15102, 15111, 15122, 15199, 15200, 15201, 15202, 15203, 15205, 15209, 15220, 15225, 15231, 15237, 15245, 15253, 15263, 15293, 15486, 15488, 15498, 15532, 15535, 15540, 15550, 15551, 15904, 15921, 15924, 15927, 16404, 16407, 16408, 16409, 16410, 16411, 16412, 16413, 16414, 16415, 16416, 16417, 16420, 16774, 16775, 16778, 16781, 17059, 17060, 17085, 17086, 17088, 17092, 17093, 17101, 17102, 17103, 17104, 17105, 17106, 17109, 17110, 17276, 17277, 17383, 17443, 17544, 17545, 17546, 17547]
# Assigning 1 at column 101
# Assigning 1 at column 117
# Assigning 1 at column 135
# Assigning 1 at column 136
# Assigning 1 at column 138
# Assigning 1 at column 200
# Assigning 1 at column 205
# Assigning 1 at column 207
# Assigning 1 at column 261
# Assigning 1 at column 262
# Assigning 1 at column 263
# Assigning 1 at column 264
# Assigning 1 at column 266
# Assigning 1 at column 273
# Assigning 1 at column 280
# Assigning 1 at column 300
# Assigning 1 at column 301
# Assigning 1 at column 387
# Assigning 1 at column 391
# Assigning 1 at column 605
# Assigning 1 at column 606
# Assigning 1 at column 608
# Assigning 1 at column 609
# Assigning 1 at column 611
# Assigning 1 at column 612
# Assigning 1 at column 614
# Assigning 1 at column 619
# Assigning 1 at column 629
# Assigning 1 at column 641
# Assigning 1 at column 675
# Assigning 1 at column 676
# Assigning 1 at column 677
# Assigning 1 at column 680
# Assigning 1 at column 681
# Assigning 1 at column 682
# Assigning 1 at column 732
# Assigning 1 at column 735
# Assigning 1 at column 737
# Assigning 1 at column 765
# Assigning 1 at column 776
# Assigning 1 at column 780
# Assigning 1 at column 785
# Assigning 1 at column 1004
# Assigning 1 at column 1008
# Assigning 1 at column 1010
# Assigning 1 at column 1055
# Assigning 1 at column 1088
# Assigning 1 at column 1089
# Assigning 1 at column 1100
# Assigning 1 at column 1101
# Assigning 1 at column 1108
# Assigning 1 at column 1117
# Assigning 1 at column 1120
# Assigning 1 at column 1156
# Assigning 1 at column 1164
# Assigning 1 at column 1206
# Assigning 1 at column 1207
# Assigning 1 at column 1432
# Assigning 1 at column 1433
# Assigning 1 at column 1434
# Assigning 1 at column 1441
# Assigning 1 at column 1442
# Assigning 1 at column 1444
# Assigning 1 at column 1448
# Assigning 1 at column 1456
# Assigning 1 at column 1457
# Assigning 1 at column 1458
# Assigning 1 at column 1459
# Assigning 1 at column 1460
# Assigning 1 at column 1461
# Assigning 1 at column 1462
# Assigning 1 at column 2441
# Assigning 1 at column 2447
# Assigning 1 at column 2448
# Assigning 1 at column 2452
# Assigning 1 at column 2453
# Assigning 1 at column 2454
# Assigning 1 at column 2455
# Assigning 1 at column 2456
# Assigning 1 at column 2457
# Assigning 1 at column 2458
# Assigning 1 at column 2461
# Assigning 1 at column 2463
# Assigning 1 at column 2464
# Assigning 1 at column 2465
# Assigning 1 at column 2466
# Assigning 1 at column 2468
# Assigning 1 at column 2470
# Assigning 1 at column 2472
# Assigning 1 at column 2485
# Assigning 1 at column 2654
# Assigning 1 at column 2656
# Assigning 1 at column 2659
# Assigning 1 at column 2661
# Assigning 1 at column 2930
# Assigning 1 at column 2947
# Assigning 1 at column 2960
# Assigning 1 at column 2961
# Assigning 1 at column 2963
# Assigning 1 at column 2964
# Assigning 1 at column 2965
# Assigning 1 at column 3282
# Assigning 1 at column 3285
# Assigning 1 at column 3286
# Assigning 1 at column 3291
# Assigning 1 at column 3292
# Assigning 1 at column 3295
# Assigning 1 at column 3405
# Assigning 1 at column 3408
# Assigning 1 at column 3410
# Assigning 1 at column 3411
# Assigning 1 at column 3412
# Assigning 1 at column 3413
# Assigning 1 at column 4194
# Assigning 1 at column 4204
# Assigning 1 at column 4205
# Assigning 1 at column 4232
# Assigning 1 at column 4233
# Assigning 1 at column 4234
# Assigning 1 at column 4236
# Assigning 1 at column 4237
# Assigning 1 at column 4241
# Assigning 1 at column 4413
# Assigning 1 at column 4414
# Assigning 1 at column 4415
# Assigning 1 at column 4418
# Assigning 1 at column 4420
# Assigning 1 at column 4421
# Assigning 1 at column 4424
# Assigning 1 at column 4521
# Assigning 1 at column 4522
# Assigning 1 at column 4524
# Assigning 1 at column 4585
# Assigning 1 at column 4637
# Assigning 1 at column 4641
# Assigning 1 at column 4642
# Assigning 1 at column 4643
# Assigning 1 at column 4652
# Assigning 1 at column 4653
# Assigning 1 at column 4654
# Assigning 1 at column 4675
# Assigning 1 at column 4682
# Assigning 1 at column 4683
# Assigning 1 at column 4684
# Assigning 1 at column 4686
# Assigning 1 at column 4687
# Assigning 1 at column 4688
# Assigning 1 at column 4693
# Assigning 1 at column 4696
# Assigning 1 at column 4697
# Assigning 1 at column 4704
# Assigning 1 at column 4714
# Assigning 1 at column 4817
# Assigning 1 at column 4819
# Assigning 1 at column 4826
# Assigning 1 at column 4909
# Assigning 1 at column 4910
# Assigning 1 at column 4911
# Assigning 1 at column 4912
# Assigning 1 at column 4913
# Assigning 1 at column 4915
# Assigning 1 at column 4928
# Assigning 1 at column 4929
# Assigning 1 at column 4930
# Assigning 1 at column 4934
# Assigning 1 at column 4935
# Assigning 1 at column 4946
# Assigning 1 at column 4948
# Assigning 1 at column 4951
# Assigning 1 at column 4954
# Assigning 1 at column 4955
# Assigning 1 at column 4963
# Assigning 1 at column 4965
# Assigning 1 at column 4980
# Assigning 1 at column 5086
# Assigning 1 at column 5106
# Assigning 1 at column 5107
# Assigning 1 at column 5108
# Assigning 1 at column 5109
# Assigning 1 at column 5111
# Assigning 1 at column 5128
# Assigning 1 at column 5129
# Assigning 1 at column 5134
# Assigning 1 at column 5135
# Assigning 1 at column 5168
# Assigning 1 at column 5169
# Assigning 1 at column 5171
# Assigning 1 at column 5173
# Assigning 1 at column 5174
# Assigning 1 at column 6066
# Assigning 1 at column 6067
# Assigning 1 at column 6068
# Assigning 1 at column 6070
# Assigning 1 at column 6071
# Assigning 1 at column 6072
# Assigning 1 at column 6095
# Assigning 1 at column 6096
# Assigning 1 at column 6099
# Assigning 1 at column 6101
# Assigning 1 at column 6440
# Assigning 1 at column 6441
# Assigning 1 at column 6442
# Assigning 1 at column 6443
# Assigning 1 at column 6444
# Assigning 1 at column 6448
# Assigning 1 at column 6453
# Assigning 1 at column 6454
# Assigning 1 at column 6455
# Assigning 1 at column 6456
# Assigning 1 at column 6460
# Assigning 1 at column 6697
# Assigning 1 at column 6853
# Assigning 1 at column 6855
# Assigning 1 at column 7029
# Assigning 1 at column 7034
# Assigning 1 at column 7106
# Assigning 1 at column 7108
# Assigning 1 at column 7112
# Assigning 1 at column 7113
# Assigning 1 at column 7118
# Assigning 1 at column 7131
# Assigning 1 at column 7144
# Assigning 1 at column 7174
# Assigning 1 at column 7175
# Assigning 1 at column 7178
# Assigning 1 at column 7179
# Assigning 1 at column 7182
# Assigning 1 at column 7184
# Assigning 1 at column 7186
# Assigning 1 at column 7364
# Assigning 1 at column 7366
# Assigning 1 at column 7369
# Assigning 1 at column 7578
# Assigning 1 at column 7639
# Assigning 1 at column 7641
# Assigning 1 at column 7642
# Assigning 1 at column 7653
# Assigning 1 at column 7654
# Assigning 1 at column 7655
# Assigning 1 at column 7657
# Assigning 1 at column 7658
# Assigning 1 at column 7670
# Assigning 1 at column 7671
# Assigning 1 at column 8446
# Assigning 1 at column 8447
# Assigning 1 at column 8450
# Assigning 1 at column 8451
# Assigning 1 at column 8632
# Assigning 1 at column 8633
# Assigning 1 at column 8634
# Assigning 1 at column 8635
# Assigning 1 at column 8637
# Assigning 1 at column 8797
# Assigning 1 at column 8798
# Assigning 1 at column 8799
# Assigning 1 at column 8800
# Assigning 1 at column 8801
# Assigning 1 at column 8984
# Assigning 1 at column 8985
# Assigning 1 at column 8986
# Assigning 1 at column 8987
# Assigning 1 at column 8988
# Assigning 1 at column 8990
# Assigning 1 at column 8992
# Assigning 1 at column 9033
# Assigning 1 at column 9034
# Assigning 1 at column 9035
# Assigning 1 at column 9037
# Assigning 1 at column 9038
# Assigning 1 at column 9039
# Assigning 1 at column 9041
# Assigning 1 at column 9042
# Assigning 1 at column 9044
# Assigning 1 at column 9045
# Assigning 1 at column 9048
# Assigning 1 at column 9049
# Assigning 1 at column 9051
# Assigning 1 at column 9053
# Assigning 1 at column 9055
# Assigning 1 at column 9056
# Assigning 1 at column 9057
# Assigning 1 at column 9608
# Assigning 1 at column 9609
# Assigning 1 at column 9611
# Assigning 1 at column 9612
# Assigning 1 at column 9621
# Assigning 1 at column 10348
# Assigning 1 at column 10349
# Assigning 1 at column 10350
# Assigning 1 at column 10375
# Assigning 1 at column 10376
# Assigning 1 at column 10379
# Assigning 1 at column 10607
# Assigning 1 at column 10608
# Assigning 1 at column 10610
# Assigning 1 at column 10740
# Assigning 1 at column 10795
# Assigning 1 at column 10797
# Assigning 1 at column 10798
# Assigning 1 at column 10799
# Assigning 1 at column 10938
# Assigning 1 at column 11115
# Assigning 1 at column 11117
# Assigning 1 at column 11171
# Assigning 1 at column 11172
# Assigning 1 at column 11173
# Assigning 1 at column 11174
# Assigning 1 at column 11175
# Assigning 1 at column 11176
# Assigning 1 at column 11300
# Assigning 1 at column 11301
# Assigning 1 at column 11302
# Assigning 1 at column 11305
# Assigning 1 at column 11306
# Assigning 1 at column 11307
# Assigning 1 at column 11308
# Assigning 1 at column 11313
# Assigning 1 at column 11315
# Assigning 1 at column 11316
# Assigning 1 at column 11320
# Assigning 1 at column 12049
# Assigning 1 at column 12053
# Assigning 1 at column 12324
# Assigning 1 at column 12325
# Assigning 1 at column 12327
# Assigning 1 at column 12937
# Assigning 1 at column 12938
# Assigning 1 at column 12939
# Assigning 1 at column 12941
# Assigning 1 at column 12945
# Assigning 1 at column 12946
# Assigning 1 at column 12947
# Assigning 1 at column 13134
# Assigning 1 at column 13209
# Assigning 1 at column 13210
# Assigning 1 at column 13211
# Assigning 1 at column 13212
# Assigning 1 at column 13214
# Assigning 1 at column 13381
# Assigning 1 at column 13382
# Assigning 1 at column 13384
# Assigning 1 at column 13676
# Assigning 1 at column 13730
# Assigning 1 at column 13777
# Assigning 1 at column 13778
# Assigning 1 at column 13780
# Assigning 1 at column 13782
# Assigning 1 at column 13783
# Assigning 1 at column 13786
# Assigning 1 at column 14272
# Assigning 1 at column 14282
# Assigning 1 at column 14283
# Assigning 1 at column 14286
# Assigning 1 at column 14516
# Assigning 1 at column 14517
# Assigning 1 at column 14518
# Assigning 1 at column 14519
# Assigning 1 at column 14520
# Assigning 1 at column 14521
# Assigning 1 at column 14525
# Assigning 1 at column 14527
# Assigning 1 at column 14529
# Assigning 1 at column 14531
# Assigning 1 at column 14535
# Assigning 1 at column 14537
# Assigning 1 at column 14539
# Assigning 1 at column 14542
# Assigning 1 at column 14546
# Assigning 1 at column 14548
# Assigning 1 at column 14696
# Assigning 1 at column 14697
# Assigning 1 at column 14700
# Assigning 1 at column 14706
# Assigning 1 at column 14723
# Assigning 1 at column 14746
# Assigning 1 at column 14895
# Assigning 1 at column 14897
# Assigning 1 at column 14898
# Assigning 1 at column 14899
# Assigning 1 at column 14900
# Assigning 1 at column 14901
# Assigning 1 at column 14908
# Assigning 1 at column 14909
# Assigning 1 at column 14910
# Assigning 1 at column 14911
# Assigning 1 at column 14915
# Assigning 1 at column 14925
# Assigning 1 at column 14974
# Assigning 1 at column 14978
# Assigning 1 at column 14979
# Assigning 1 at column 14980
# Assigning 1 at column 14984
# Assigning 1 at column 14985
# Assigning 1 at column 14986
# Assigning 1 at column 14988
# Assigning 1 at column 14989
# Assigning 1 at column 14991
# Assigning 1 at column 14994
# Assigning 1 at column 14997
# Assigning 1 at column 15001
# Assigning 1 at column 15003
# Assigning 1 at column 15006
# Assigning 1 at column 15093
# Assigning 1 at column 15102
# Assigning 1 at column 15111
# Assigning 1 at column 15122
# Assigning 1 at column 15199
# Assigning 1 at column 15200
# Assigning 1 at column 15201
# Assigning 1 at column 15202
# Assigning 1 at column 15203
# Assigning 1 at column 15205
# Assigning 1 at column 15209
# Assigning 1 at column 15220
# Assigning 1 at column 15225
# Assigning 1 at column 15231
# Assigning 1 at column 15237
# Assigning 1 at column 15245
# Assigning 1 at column 15253
# Assigning 1 at column 15263
# Assigning 1 at column 15293
# Assigning 1 at column 15486
# Assigning 1 at column 15488
# Assigning 1 at column 15498
# Assigning 1 at column 15532
# Assigning 1 at column 15535
# Assigning 1 at column 15540
# Assigning 1 at column 15550
# Assigning 1 at column 15551
# Assigning 1 at column 15904
# Assigning 1 at column 15921
# Assigning 1 at column 15924
# Assigning 1 at column 15927
# Assigning 1 at column 16404
# Assigning 1 at column 16407
# Assigning 1 at column 16408
# Assigning 1 at column 16409
# Assigning 1 at column 16410
# Assigning 1 at column 16411
# Assigning 1 at column 16412
# Assigning 1 at column 16413
# Assigning 1 at column 16414
# Assigning 1 at column 16415
# Assigning 1 at column 16416
# Assigning 1 at column 16417
# Assigning 1 at column 16420
# Assigning 1 at column 16774
# Assigning 1 at column 16775
# Assigning 1 at column 16778
# Assigning 1 at column 16781
# Assigning 1 at column 17059
# Assigning 1 at column 17060
# Assigning 1 at column 17085
# Assigning 1 at column 17086
# Assigning 1 at column 17088
# Assigning 1 at column 17092
# Assigning 1 at column 17093
# Assigning 1 at column 17101
# Assigning 1 at column 17102
# Assigning 1 at column 17103
# Assigning 1 at column 17104
# Assigning 1 at column 17105
# Assigning 1 at column 17106
# Assigning 1 at column 17109
# Assigning 1 at column 17110
# Assigning 1 at column 17276
# Assigning 1 at column 17277
# Assigning 1 at column 17383
# Assigning 1 at column 17443
# Assigning 1 at column 17544
# Assigning 1 at column 17545
# Assigning 1 at column 17546
# Assigning 1 at column 17547

# %% [markdown]
# # Filter twitches

# %% [markdown]
# ### Based on proximity to wake motions

# %%
def filter_twitches_by_awake_proximity(inds_twitches, inds_active_state, min_distance=None):
    filtered_twitches = []

    for idx_twitch in inds_twitches:
        distance = np.abs(inds_active_state - idx_twitch)
        if np.min(distance) > min_distance:
            filtered_twitches.append(idx_twitch)

    filtered_twitches = np.array(filtered_twitches)

    return filtered_twitches

# %%
inds_twitches_filtered_step1 = filter_twitches_by_awake_proximity(inds_twitches_unfiltered, inds_active_state, min_distance=twitch_min_distance_from_active)

# %% [markdown]
# ### Based on duration

# %%
inds_twitches_segments = find_sequential_groups(inds_twitches_filtered_step1)
active_motion_segments = find_sequential_groups(inds_active_state[0])
resting_motion_segments = find_sequential_groups(inds_rest_state[0])

# %%
for seg in inds_twitches_segments:

    time = np.arange(len(seg))/framerate
    plt.plot(time, motion_energy[seg])
    plt.title('twitch duration (s)')
    plt.xlabel('sec')
plt.savefig(save_dir_videography / 'twitch_duration_non_filtered.png')

# %%
twitch_duration_max
# Out:
# 15

# %%
# filter twitches based on duration 
def filter_segments_by_duration(segments, duration_threshold):
# Filter out groups based on the duration threshold
    return [twitches for twitches in segments if len(twitches) <= duration_threshold]

# %%
# get filtered twitches 
inds_twitches_filtered_step2 = filter_segments_by_duration(inds_twitches_segments, twitch_duration_max)

# %% [markdown]
# # Binarise twitch

# %%
def binarise_twitch(motion_energy, twitch_segments):

    # Initialize bin_twitch   
    bin_twitch = np.zeros(len(motion_energy))

    # flatten the nested list
    flat_inds = [idx for segment in twitch_segments for idx in segment] # filtered corrected twitches 

    print("Flattened Indices:", flat_inds)

    # Assign 1 to twitch inds
    for idx in flat_inds:
        if idx < len(motion_energy):  # Ensure index is within bounds
            bin_twitch[idx] = 1
            print(f"Assigning 1 at column {idx}")
        else:
            print(f"Skipping out-of-bounds index: {idx}")
    return bin_twitch

# %%
bin_twitch = binarise_twitch(motion_energy, inds_twitches_filtered_step2)
# Out:
# Flattened Indices: [101, 117, 135, 136, 138, 200, 205, 207, 261, 262, 263, 264, 266, 273, 280, 300, 301, 387, 391, 605, 606, 608, 609, 611, 612, 614, 619, 629, 641, 675, 676, 677, 680, 681, 682, 732, 735, 737, 765, 776, 780, 785, 1004, 1008, 1010, 1055, 1088, 1089, 1100, 1101, 1108, 1117, 1120, 1156, 4237, 4241, 4413, 4414, 4415, 4418, 4420, 4421, 4424, 4521, 4522, 4524, 4585, 4637, 4641, 4642, 4643, 4652, 4653, 4654, 4675, 4682, 4683, 4684, 4686, 4687, 4688, 4693, 4696, 4697, 4704, 4714, 4817, 4819, 4826, 4909, 4910, 4911, 4912, 4913, 4915, 4928, 4929, 4930, 4934, 4935, 4946, 4948, 4951, 4954, 4955, 4963, 4965, 4980, 5086, 5106, 5107, 5108, 5109, 5111, 5128, 5129, 6440, 6441, 6442, 6443, 6444, 6448, 6453, 6454, 6455, 6456, 6460, 6697, 6853, 6855, 7029, 7034, 7106, 7108, 7112, 7113, 7118, 7131, 7144, 7174, 7175, 7178, 7179, 7182, 7184, 7186, 7364, 7366, 7369, 7578, 8632, 8633, 8634, 8635, 8637, 8797, 8798, 8799, 8800, 8801, 8984, 8985, 8986, 8987, 8988, 8990, 8992, 10607, 10608, 10610, 10740, 10795, 10797, 10798, 10799, 10938, 11115, 11117, 11171, 11172, 11173, 11174, 11175, 11176, 13134, 13209, 13210, 13211, 13212, 13214, 13381, 13382, 13384, 13676, 13730, 14516, 14517, 14518, 14519, 14520, 14521, 14525, 14527, 14529, 14531, 14535, 14537, 14539, 14542, 14546, 14548, 14696, 14697, 14700, 14706, 14723, 14746, 14895, 14897, 14898, 14899, 14900, 14901, 14908, 14909, 14910, 14911, 14915, 14925, 14974, 14978, 14979, 14980, 14984, 14985, 14986, 14988, 14989, 14991, 14994, 14997, 15001, 15003, 15006, 15093, 15102, 15111, 15122, 15199, 15200, 15201, 15202, 15203, 15205, 15209, 15220, 15225, 15231, 15237, 15245, 15253, 15263, 15293, 15486, 15488, 15498, 15532, 15535, 17059, 17060, 17085, 17086, 17088, 17092, 17093, 17101, 17102, 17103, 17104, 17105, 17106, 17109, 17110, 17276, 17277, 17383, 17443]
# Assigning 1 at column 101
# Assigning 1 at column 117
# Assigning 1 at column 135
# Assigning 1 at column 136
# Assigning 1 at column 138
# Assigning 1 at column 200
# Assigning 1 at column 205
# Assigning 1 at column 207
# Assigning 1 at column 261
# Assigning 1 at column 262
# Assigning 1 at column 263
# Assigning 1 at column 264
# Assigning 1 at column 266
# Assigning 1 at column 273
# Assigning 1 at column 280
# Assigning 1 at column 300
# Assigning 1 at column 301
# Assigning 1 at column 387
# Assigning 1 at column 391
# Assigning 1 at column 605
# Assigning 1 at column 606
# Assigning 1 at column 608
# Assigning 1 at column 609
# Assigning 1 at column 611
# Assigning 1 at column 612
# Assigning 1 at column 614
# Assigning 1 at column 619
# Assigning 1 at column 629
# Assigning 1 at column 641
# Assigning 1 at column 675
# Assigning 1 at column 676
# Assigning 1 at column 677
# Assigning 1 at column 680
# Assigning 1 at column 681
# Assigning 1 at column 682
# Assigning 1 at column 732
# Assigning 1 at column 735
# Assigning 1 at column 737
# Assigning 1 at column 765
# Assigning 1 at column 776
# Assigning 1 at column 780
# Assigning 1 at column 785
# Assigning 1 at column 1004
# Assigning 1 at column 1008
# Assigning 1 at column 1010
# Assigning 1 at column 1055
# Assigning 1 at column 1088
# Assigning 1 at column 1089
# Assigning 1 at column 1100
# Assigning 1 at column 1101
# Assigning 1 at column 1108
# Assigning 1 at column 1117
# Assigning 1 at column 1120
# Assigning 1 at column 1156
# Assigning 1 at column 4237
# Assigning 1 at column 4241
# Assigning 1 at column 4413
# Assigning 1 at column 4414
# Assigning 1 at column 4415
# Assigning 1 at column 4418
# Assigning 1 at column 4420
# Assigning 1 at column 4421
# Assigning 1 at column 4424
# Assigning 1 at column 4521
# Assigning 1 at column 4522
# Assigning 1 at column 4524
# Assigning 1 at column 4585
# Assigning 1 at column 4637
# Assigning 1 at column 4641
# Assigning 1 at column 4642
# Assigning 1 at column 4643
# Assigning 1 at column 4652
# Assigning 1 at column 4653
# Assigning 1 at column 4654
# Assigning 1 at column 4675
# Assigning 1 at column 4682
# Assigning 1 at column 4683
# Assigning 1 at column 4684
# Assigning 1 at column 4686
# Assigning 1 at column 4687
# Assigning 1 at column 4688
# Assigning 1 at column 4693
# Assigning 1 at column 4696
# Assigning 1 at column 4697
# Assigning 1 at column 4704
# Assigning 1 at column 4714
# Assigning 1 at column 4817
# Assigning 1 at column 4819
# Assigning 1 at column 4826
# Assigning 1 at column 4909
# Assigning 1 at column 4910
# Assigning 1 at column 4911
# Assigning 1 at column 4912
# Assigning 1 at column 4913
# Assigning 1 at column 4915
# Assigning 1 at column 4928
# Assigning 1 at column 4929
# Assigning 1 at column 4930
# Assigning 1 at column 4934
# Assigning 1 at column 4935
# Assigning 1 at column 4946
# Assigning 1 at column 4948
# Assigning 1 at column 4951
# Assigning 1 at column 4954
# Assigning 1 at column 4955
# Assigning 1 at column 4963
# Assigning 1 at column 4965
# Assigning 1 at column 4980
# Assigning 1 at column 5086
# Assigning 1 at column 5106
# Assigning 1 at column 5107
# Assigning 1 at column 5108
# Assigning 1 at column 5109
# Assigning 1 at column 5111
# Assigning 1 at column 5128
# Assigning 1 at column 5129
# Assigning 1 at column 6440
# Assigning 1 at column 6441
# Assigning 1 at column 6442
# Assigning 1 at column 6443
# Assigning 1 at column 6444
# Assigning 1 at column 6448
# Assigning 1 at column 6453
# Assigning 1 at column 6454
# Assigning 1 at column 6455
# Assigning 1 at column 6456
# Assigning 1 at column 6460
# Assigning 1 at column 6697
# Assigning 1 at column 6853
# Assigning 1 at column 6855
# Assigning 1 at column 7029
# Assigning 1 at column 7034
# Assigning 1 at column 7106
# Assigning 1 at column 7108
# Assigning 1 at column 7112
# Assigning 1 at column 7113
# Assigning 1 at column 7118
# Assigning 1 at column 7131
# Assigning 1 at column 7144
# Assigning 1 at column 7174
# Assigning 1 at column 7175
# Assigning 1 at column 7178
# Assigning 1 at column 7179
# Assigning 1 at column 7182
# Assigning 1 at column 7184
# Assigning 1 at column 7186
# Assigning 1 at column 7364
# Assigning 1 at column 7366
# Assigning 1 at column 7369
# Assigning 1 at column 7578
# Assigning 1 at column 8632
# Assigning 1 at column 8633
# Assigning 1 at column 8634
# Assigning 1 at column 8635
# Assigning 1 at column 8637
# Assigning 1 at column 8797
# Assigning 1 at column 8798
# Assigning 1 at column 8799
# Assigning 1 at column 8800
# Assigning 1 at column 8801
# Assigning 1 at column 8984
# Assigning 1 at column 8985
# Assigning 1 at column 8986
# Assigning 1 at column 8987
# Assigning 1 at column 8988
# Assigning 1 at column 8990
# Assigning 1 at column 8992
# Assigning 1 at column 10607
# Assigning 1 at column 10608
# Assigning 1 at column 10610
# Assigning 1 at column 10740
# Assigning 1 at column 10795
# Assigning 1 at column 10797
# Assigning 1 at column 10798
# Assigning 1 at column 10799
# Assigning 1 at column 10938
# Assigning 1 at column 11115
# Assigning 1 at column 11117
# Assigning 1 at column 11171
# Assigning 1 at column 11172
# Assigning 1 at column 11173
# Assigning 1 at column 11174
# Assigning 1 at column 11175
# Assigning 1 at column 11176
# Assigning 1 at column 13134
# Assigning 1 at column 13209
# Assigning 1 at column 13210
# Assigning 1 at column 13211
# Assigning 1 at column 13212
# Assigning 1 at column 13214
# Assigning 1 at column 13381
# Assigning 1 at column 13382
# Assigning 1 at column 13384
# Assigning 1 at column 13676
# Assigning 1 at column 13730
# Assigning 1 at column 14516
# Assigning 1 at column 14517
# Assigning 1 at column 14518
# Assigning 1 at column 14519
# Assigning 1 at column 14520
# Assigning 1 at column 14521
# Assigning 1 at column 14525
# Assigning 1 at column 14527
# Assigning 1 at column 14529
# Assigning 1 at column 14531
# Assigning 1 at column 14535
# Assigning 1 at column 14537
# Assigning 1 at column 14539
# Assigning 1 at column 14542
# Assigning 1 at column 14546
# Assigning 1 at column 14548
# Assigning 1 at column 14696
# Assigning 1 at column 14697
# Assigning 1 at column 14700
# Assigning 1 at column 14706
# Assigning 1 at column 14723
# Assigning 1 at column 14746
# Assigning 1 at column 14895
# Assigning 1 at column 14897
# Assigning 1 at column 14898
# Assigning 1 at column 14899
# Assigning 1 at column 14900
# Assigning 1 at column 14901
# Assigning 1 at column 14908
# Assigning 1 at column 14909
# Assigning 1 at column 14910
# Assigning 1 at column 14911
# Assigning 1 at column 14915
# Assigning 1 at column 14925
# Assigning 1 at column 14974
# Assigning 1 at column 14978
# Assigning 1 at column 14979
# Assigning 1 at column 14980
# Assigning 1 at column 14984
# Assigning 1 at column 14985
# Assigning 1 at column 14986
# Assigning 1 at column 14988
# Assigning 1 at column 14989
# Assigning 1 at column 14991
# Assigning 1 at column 14994
# Assigning 1 at column 14997
# Assigning 1 at column 15001
# Assigning 1 at column 15003
# Assigning 1 at column 15006
# Assigning 1 at column 15093
# Assigning 1 at column 15102
# Assigning 1 at column 15111
# Assigning 1 at column 15122
# Assigning 1 at column 15199
# Assigning 1 at column 15200
# Assigning 1 at column 15201
# Assigning 1 at column 15202
# Assigning 1 at column 15203
# Assigning 1 at column 15205
# Assigning 1 at column 15209
# Assigning 1 at column 15220
# Assigning 1 at column 15225
# Assigning 1 at column 15231
# Assigning 1 at column 15237
# Assigning 1 at column 15245
# Assigning 1 at column 15253
# Assigning 1 at column 15263
# Assigning 1 at column 15293
# Assigning 1 at column 15486
# Assigning 1 at column 15488
# Assigning 1 at column 15498
# Assigning 1 at column 15532
# Assigning 1 at column 15535
# Assigning 1 at column 17059
# Assigning 1 at column 17060
# Assigning 1 at column 17085
# Assigning 1 at column 17086
# Assigning 1 at column 17088
# Assigning 1 at column 17092
# Assigning 1 at column 17093
# Assigning 1 at column 17101
# Assigning 1 at column 17102
# Assigning 1 at column 17103
# Assigning 1 at column 17104
# Assigning 1 at column 17105
# Assigning 1 at column 17106
# Assigning 1 at column 17109
# Assigning 1 at column 17110
# Assigning 1 at column 17276
# Assigning 1 at column 17277
# Assigning 1 at column 17383
# Assigning 1 at column 17443

# %%
len(inds_twitches_filtered_step2)
# Out:
# 183

# %% [markdown]
# # Filter twitches based on inter-twitch-interval (aka discard bursts, keep sparse 'trusted' twitches)

# %%
def remove_twitch_bursts(twitch_binary, framerate, min_interval=1):
    """
    Removes all twitches that occur within `min_interval` seconds of another twitch.
    Both twitches in a burst/close proximimity are excluded.
    
    Parameters:
        twitch_binary (np.ndarray): Binary vector of twitch detections (1 = twitch, 0 = no twitch)
        fs (float): framerate (Hz)
        min_interval (float): minimum interval required between twitches for those to be detected (in sec)
    
    Returns:
        np.ndarray: filtered binary twitch array 
    """
    twitch_indices = np.where(twitch_binary == 1)[0]
    to_remove = set()
    
    # Compare each twitch to the next one
    for i in range(len(twitch_indices) - 1):
        curr_idx = twitch_indices[i]
        next_idx = twitch_indices[i + 1]
        interval = (next_idx - curr_idx) / framerate # in sec 
        
        if interval < min_interval:
            to_remove.add(curr_idx)
            to_remove.add(next_idx)
    
    filtered_twitches = np.copy(twitch_binary)
    filtered_twitches[list(to_remove)] = 0
    return filtered_twitches

# %%
np.where(bin_twitch==1) #before
# Out:
# (array([  101,   117,   135,   136,   138,   200,   205,   207,   261,
#           262,   263,   264,   266,   273,   280,   300,   301,   387,
#           391,   605,   606,   608,   609,   611,   612,   614,   619,
#           629,   641,   675,   676,   677,   680,   681,   682,   732,
#           735,   737,   765,   776,   780,   785,  1004,  1008,  1010,
#          1055,  1088,  1089,  1100,  1101,  1108,  1117,  1120,  1156,
#          4237,  4241,  4413,  4414,  4415,  4418,  4420,  4421,  4424,
#          4521,  4522,  4524,  4585,  4637,  4641,  4642,  4643,  4652,
#          4653,  4654,  4675,  4682,  4683,  4684,  4686,  4687,  4688,
#          4693,  4696,  4697,  4704,  4714,  4817,  4819,  4826,  4909,
#          4910,  4911,  4912,  4913,  4915,  4928,  4929,  4930,  4934,
#          4935,  4946,  4948,  4951,  4954,  4955,  4963,  4965,  4980,
#          5086,  5106,  5107,  5108,  5109,  5111,  5128,  5129,  6440,
#          6441,  6442,  6443,  6444,  6448,  6453,  6454,  6455,  6456,
#          6460,  6697,  6853,  6855,  7029,  7034,  7106,  7108,  7112,
#          7113,  7118,  7131,  7144,  7174,  7175,  7178,  7179,  7182,
#          7184,  7186,  7364,  7366,  7369,  7578,  8632,  8633,  8634,
#          8635,  8637,  8797,  8798,  8799,  8800,  8801,  8984,  8985,
#          8986,  8987,  8988,  8990,  8992, 10607, 10608, 10610, 10740,
#         10795, 10797, 10798, 10799, 10938, 11115, 11117, 11171, 11172,
#         11173, 11174, 11175, 11176, 13134, 13209, 13210, 13211, 13212,
#         13214, 13381, 13382, 13384, 13676, 13730, 14516, 14517, 14518,
#         14519, 14520, 14521, 14525, 14527, 14529, 14531, 14535, 14537,
#         14539, 14542, 14546, 14548, 14696, 14697, 14700, 14706, 14723,
#         14746, 14895, 14897, 14898, 14899, 14900, 14901, 14908, 14909,
#         14910, 14911, 14915, 14925, 14974, 14978, 14979, 14980, 14984,
#         14985, 14986, 14988, 14989, 14991, 14994, 14997, 15001, 15003,
#         15006, 15093, 15102, 15111, 15122, 15199, 15200, 15201, 15202,
#         15203, 15205, 15209, 15220, 15225, 15231, 15237, 15245, 15253,
#         15263, 15293, 15486, 15488, 15498, 15532, 15535, 17059, 17060,
#         17085, 17086, 17088, 17092, 17093, 17101, 17102, 17103, 17104,
#         17105, 17106, 17109, 17110, 17276, 17277, 17383, 17443],
#        dtype=int64),)

# %% [markdown]
# # Careful ! check it before

# %%
bin_twitch = remove_twitch_bursts(bin_twitch, framerate, min_interval=0.5)

# %%
len(bin_twitch)
# Out:
# 17999

# %% [markdown]
# # Define onset and offset of twitch

# %%
active_onsets = get_onsets(bin_motion_energy)
active_offsets = get_offsets(bin_motion_energy)
twitch_onsets = get_onsets(bin_twitch)
twitch_offsets = get_offsets(bin_twitch)

# %%
iti = np.diff(twitch_onsets/framerate)

plt.figure(figsize=(5,5))
plt.hist(iti.flatten(), bins=50)
plt.xlabel('sec')
plt.ylabel('twitches')
plt.show()

# most twithces occur in burst fashion

# %% [markdown]
# # Plot filtered twitches detected on motion energy

# %%
def plot_detected_twitches(
    motion_energy,
    smoothed_motion_energy,
    bin_motion_energy,
    threshold_twitches,
    threshold_motion_energy,
    inds_twitches,
    frame_ticks,
    second_ticks,
    save_dir_videography=None
):
    """
    Plot the motion energy and smoothed motion energy with twitch detection.

    Parameters:
    - motion_energy: Raw motion energy signal.
    - smoothed_motion_energy: Smoothed motion energy signal.
    - threshold_twitches: Threshold for twitch detection.
    - threshold_motion_energy: Threshold for binary motion energy.
    - inds_twitches: Indices where twitch segments start (onsets).
    - frame_ticks: Frame indices for x-axis.
    - second_ticks: Time ticks in seconds for x-axis.
    - save_dir_videography: Optional directory to save the figure.
    """
    
    fig, axs = plt.subplots(2, 1, figsize=(15, 7), dpi=300)

    # Plot raw and smoothed motion energy
    axs[0].plot(motion_energy, color='orange', linewidth=2, label='mot_en')
    axs[0].plot(smoothed_motion_energy, color='blue', linewidth=1.5, label='mot_en smoothed')
    axs[0].axhline(y=threshold_twitches, color='red', linestyle='--', label='Twitch threshold')
    axs[0].set_xticks(ticks=frame_ticks)
    axs[0].set_xticklabels(second_ticks, fontsize=12)
    axs[0].legend(loc='upper right', fontsize=10)
    axs[0].set_ylabel('mot_en', fontsize=15)
    axs[0].set_title('mot_en - twitch detection', fontsize=18)

    trio_motion_energy = bin_motion_energy.copy()
    trio_motion_energy[inds_twitches] = -1  # mark twitch segments with -1

    # Plot raw motion energy and binary motion energy (including twitch detection)
    axs[1].plot(motion_energy, color='blue', linewidth=1, label='mot_en')
    axs[1].plot(trio_motion_energy, color='darkorange', linewidth=1, label='3 states on mot_en')
    axs[1].axhline(y=threshold_twitches, color='red', linestyle='--', label='twitch threshold')
    axs[1].set_xticks(ticks=frame_ticks)
    axs[1].set_xticklabels(second_ticks, fontsize=12)
    axs[1].set_xlabel('Time (s)', fontsize=15)
    axs[1].set_title('Twitch Detection', fontsize=18)
    axs[1].legend(loc='upper right', fontsize=10)

    # Adjust layout and save the plot
    plt.subplots_adjust(hspace=0.6)

    if save_dir_videography:
        plt.savefig(save_dir_videography + 'trio_motion_energy_including_twitches.png')
        print(f"Plot saved to: {save_dir_videography + 'trio_motion_energy_including_twitches.png'}")

    plt.show()

# %%
plot_detected_twitches(
    motion_energy=motion_energy,
    smoothed_motion_energy=smoothed_motion_energy,
    bin_motion_energy=bin_motion_energy,
    threshold_twitches=twitch_threshold,
    threshold_motion_energy= binary_threshold,
    inds_twitches=twitch_onsets,
    frame_ticks=frame_ticks,
    second_ticks=second_ticks,
    save_dir_videography='twitch_detection'
)
# Out:
# Plot saved to: twitch_detectiontrio_motion_energy_including_twitches.png

# %%
n_twitches = len(twitch_onsets) 
n_active_motions = len(active_motion_segments)

# %%
# ========== SUMMARY ==========
print(f"Total active/awake motions detected: {n_active_motions}")
print(f"Total twitches detected: {n_twitches}")
# Out:
# Total active/awake motions detected: 17
# Total twitches detected: 34

# %% [markdown]
# # Final annotated motion

# %%
def get_behavior_classification(bin_putative_twitch, bin_twitch, bin_motion_energy, active_onsets, twitch_onsets):
    """
    Classify behavior states and key motion onsets.

    Parameters:
        bin_putative_twitch (np.ndarray): raw unfiltered twitch binary array
        bin_twitch (np.ndarray): filtered twitch binary array
        bin_motion_energy (np.ndarray): binarized motion energy (1 = active, 0 = rest)

    Returns:
        dict: classified behavior array and key motion index groups
    """
    classified_behavior = bin_motion_energy.copy()
    classified_behavior[twitch_onsets] = -1
    classified_behavior[active_onsets] = 1

    # 2. Complex motion onsets (filtered twitches)
    complex_motion = (bin_putative_twitch == 1) & (bin_twitch == 0) # not-twitches 

    complex_onsets = np.where((complex_motion[1:]== 1) & (complex_motion[:-1]== 0))[0] +1
    complex_offsets = np.where((complex_motion[1:] ==0) & (complex_motion[:-1] ==1))[0] +1

    complex_motion_segments = []
    for onset,offset in zip(complex_onsets, complex_offsets):
        complex_motion_segments.append((onset,offset))
        classified_behavior[onset:offset] =2 

    # Index groups
    active_and_complex_motions = np.where((classified_behavior == 1) | (classified_behavior == 2))[0]
    only_active_motions = np.where(classified_behavior == 1)[0]
    twitch_onsets = np.where(classified_behavior == -1)[0]

    return classified_behavior, active_and_complex_motions, only_active_motions, complex_motion_segments ,complex_onsets, complex_offsets

# %%
len(twitch_onsets)
# Out:
# 34

# %%
classified_behavior, active_and_complex_motions, only_active_motions, complex_motion_segments, complex_onsets, complex_offsets  = get_behavior_classification(bin_putative_twitch, bin_twitch, bin_motion_energy, active_onsets, twitch_onsets)

# %%
import matplotlib.patches as mpatches 

def plot_classified_behavior_timeline(classified_behavior, motion_signal, framerate=3, title='Classified behavior', save_dir=None):
    """
    Plots the classified behavior as a color-coded horizontal bar with motion signal and segment durations.

    Parameters:
        classified_behavior (np.ndarray): array of -1, 0, 1, 2 values (behavior states)
        motion_signal (np.ndarray): array of raw or smoothed motion energy signal
        framerate (int): sampling frequency (for time axis), default is 3 Hz
        title (str): plot title
    """
    # Create a colormap for behavior classification
    color_map = {
        -1: 'red',  # Twitch onset - red
         0: 'grey',  # Rest - gray
         1: 'blue',  # Active - blue
         2: 'cyan'   # Complex motion - orange
    }

    # Time axis (in seconds)
    time = np.arange(len(classified_behavior)) / framerate

    # Normalize the motion signal
    motion_signal_norm = (motion_signal - np.min(motion_signal)) / (np.max(motion_signal) - np.min(motion_signal))

    # Create a figure for the plot
    plt.figure(figsize=(30, 5), dpi=300)

    # Initialize start index for segment tracking
    start_idx = 0
    
    # Plot each segment with color reflecting its duration
    for i in range(1, len(classified_behavior)):
        if classified_behavior[i] != classified_behavior[start_idx]:
            # Calculate the duration of the current segment
            segment_duration = (i - start_idx) / framerate
            
            # Adjust transparency based on segment duration (longer = less transparent)
            alpha_value = 0.5
            #= min(1, segment_duration / 10)  # Duration scaled to transparency (max duration = 10s)
            
            # Ensure red (Twitch) is not too transparent
            if classified_behavior[start_idx] == -1:
                alpha_value = max(0.95, alpha_value)  # Set a baseline for red to be visible even for short durations
            elif classified_behavior[start_idx] == 1:
                alpha_value = max(0.3, alpha_value)
            elif classified_behavior[start_idx] == 2:
                alpha_value = max(0.5, alpha_value)  #   
    
            # Plot the segment with the corresponding color and adjusted alpha
            plt.bar(time[start_idx:i], np.ones(i - start_idx), color=color_map[classified_behavior[start_idx]], 
                    width=1/framerate, align='edge', alpha=alpha_value, linewidth=15)
            
            start_idx = i  # Update start index for the next segment

    # Plot motion signal on top
    plt.plot(time, motion_signal_norm, color='blue', linewidth=1)

    # Add labels and title
    plt.xlabel('Time (s)', fontsize=25)
    plt.ylabel('motion_energy', fontsize=25)
    plt.yticks([])
    plt.title(title, fontsize=35)

    # Legend
    legend_patches = [
        mpatches.Patch(color=color_map[-1], label='Twitch (-1)'),
        mpatches.Patch(color=color_map[0], label='Rest (0)'),
        mpatches.Patch(color=color_map[1], label='Active (1)'),
        mpatches.Patch(color=color_map[2], label='Complex (2)'),
    ]
    plt.legend(handles=legend_patches, loc='upper right', fontsize=15)

    plt.savefig(save_dir / 'classified_behavior.png')
    plt.tight_layout()
    plt.show()

# %%
plot_classified_behavior_timeline(classified_behavior, motion_energy, framerate=framerate, save_dir=save_dir_videography)

# %% [markdown]
# ## add final twitch segments, active motion segments, complex segments , rest segments

# %% [markdown]
# # Save all outputs

# %%
classified_behavior, active_and_complex_motions, only_active_motions, complex_motion_segments, complex_onsets, complex_offsets
auto_detection = {
    'frequency' : framerate,
    # 'binary_threshold' : 'otsu',
    # 'twitch_threshold' : 'li',
    '+- active_motion_min_distance' : twitch_min_distance_from_active/framerate , #sec
    'motion_energy_downsampled_2x' : motion_energy,
    'binary_motion_energy' : bin_motion_energy,

    'classified_behavior': classified_behavior, # np.array: classified behavior (pre-curation): 0,1,-1,2 aka Rest, Active, Twitch, Complex
    
    'active_motion_onsets' : active_motion_onsets,
    'active_motion_offsets' : active_motion_offsets,
    'active_motion_segments' : active_motion_segments,

    'active_and_complex_motions':active_and_complex_motions,
    'only_active_motions':only_active_motions,

    'complex_onsets': complex_onsets,
    'complex_offsets': complex_onsets,
    'complex_motion_segments' : complex_motion_segments, #just (onset,offset)

    'binary_twich':bin_twitch, #binary array where 1 == twitch 
    'inds_twitches_segments': inds_twitches_segments,
    'n_twitches' : n_twitches, # no. of twitches 
    'twitch_onsets': twitch_onsets,  # onsets 
    'twitch_offsets': twitch_offsets  # offsets     
}

np.save(save_dir + f'auto_detection_{ds}.npy', auto_detection)
# np.savez(save_dir + f"auto_detection_{ds}.npz", **auto_detection)

# %%
classified_behavior
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
keys_to_excel = [
    'twitch_onsets',
    'twitch_offsets',
    'active_motion_onsets',
    'active_motion_offsets',
    'complex_onsets',
    'complex_offsets'
]
export_to_excel = {key:auto_detection[key] for key in keys_to_excel}

# %%
max_length = max(len(value) for value in export_to_excel.values()) 

# Pad arrays to the maximum length
for key, value in export_to_excel.items():
    # Cast integer arrays to float before padding
    if len(value) < max_length:
        export_to_excel[key] = np.pad(np.array(value, dtype=float), (0, max_length - len(value)), constant_values=np.nan)

# Now create the DataFrame
df = pd.DataFrame(export_to_excel)

# Export to Excel
output_path = os.path.join(save_dir_videography, 'beh_annoations.xls')
df.to_excel(output_path, index=False, engine='openpyxl')

# %%
save_dir_videography
# Out:
# WindowsPath('C:/Users/zaggila/Documents/pixelNMF/data/sz89_2024-06-06_a_cell_control/videography_processing_non_avg')

# %% [markdown]
# # Write on video for validation (manual curation)

# %%
movie_path
# Out:
# 'C:\\Users\\zaggila\\Documents\\pixelNMF\\data\\sz89_2024-06-06_a_cell_control\\cam_crop.tif'

# %%
tiff = io.imread(movie_path, plugin='tifffile') #pil loads on snapshot 

# making sure smallest value of tiff is zero - just a linear transform, shouldn't affect NMF ? 
tiff -= np.min(tiff)
print(f'Shape of video: {tiff.shape}')
# Out:
# C:\Users\zaggila\AppData\Local\Temp\ipykernel_28688\2049817810.py:1: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   tiff = io.imread(movie_path, plugin='tifffile') #pil loads on snapshot
# Shape of video: (18000, 432, 846)

# %% [markdown]
# # LossLess compression (output tiff or avi)

# %%
tiff.shape
# Out:
# (18000, 432, 846)

# %%
# Normalize if needed
tiff = tiff - np.min(tiff)
tiff = (tiff / tiff.max() * 255).astype(np.uint8)

# Convert grayscale to BGR if needed
if len(tiff.shape) == 3:  # (frames, height, width)
    tiff = np.stack([tiff] * 3, axis=-1)

# Set up AVI writer
height, width = tiff.shape[1:3] 
out = cv2.VideoWriter(
    'output_video.avi',
    cv2.VideoWriter_fourcc(*'FFV1'),  # Lossless codec (e.g., FFV1, MJPG, or XVID for near-lossless)
    15,  # FPS
    (width, height)
)

# Write frames
for frame in tiff:
    out.write(frame)
out.release()
print("Saved to output_video.avi")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[77], line 3
#       1 # Normalize if needed
#       2 tiff = tiff - np.min(tiff)
# ----> 3 tiff = (tiff / tiff.max() * 255).astype(np.uint8)
#       5 # Convert grayscale to BGR if needed
#       6 if len(tiff.shape) == 3:  # (frames, height, width)
#
# MemoryError: Unable to allocate 49.0 GiB for an array with shape (18000, 432, 846) and data type float64

# %%
# Define onset points (from onset_twitch_1d)
for onset_time in twitch_onsets:
    # Ensure onset_time is within the frame count
    if onset_time < len(tiff):
        frame = tiff[onset_time]
        frame_bgr = cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)
        
        # write 'Twitch') at a fixed location (x, y)
        cv2.putText(frame_bgr, 'Twitch onset', (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 1, cv2.LINE_AA)

        tiff[onset_time] = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2GRAY)

        # tiff[onset_time] = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2GRAY)

        print("Finished marking onset frames.")

for active_mot_onset in active_motion_onsets: 
    if active_mot_onset < len(tiff):
        frame= tiff[active_mot_onset]
        frame_bgr = cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)
        cv2.putText(frame_bgr, 'Active motion onset', (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 1, cv2.LINE_AA)
        tiff[active_mot_onset] = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2GRAY) 

for active_motion_offset in active_motion_offsets:
    if active_motion_offset < len(tiff):
        frame = tiff[active_motion_offset]
        frame_bgr = cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)
        cv2.putText(frame_bgr, 'Active motion offset', (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 1, cv2.LINE_AA)
        tiff[active_motion_offset] = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2GRAY)   

for complex_motion_onset in complex_onsets:
    if complex_motion_onset < len(tiff):
        frame=tiff[complex_motion_onset]
        frame_bgr = cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)
        cv2.putText(frame_bgr, 'Complex motion', (50,100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 1, cv2.LINE_AA)
        tiff[complex_motion_onset] = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2GRAY)

# %%
active_motion_onsets

# %%
save_dir_videography

# %%
len(twitch_onsets)

# %%
output_dir = save_dir_videography / '_validation_twitch_video.tif'
# Export the marked frames as TIFF sequence
os.makedirs(output_dir, exist_ok=True)

# Save frames as TIFF files
for i, frame in enumerate(tiff):
    output_path = os.path.join(output_dir, f"frame_{i:04d}.tiff")
    img = Image.fromarray(frame)
    img.save(output_path)
    

print(f"Exported {len(tiff)} frames to {output_dir}")
